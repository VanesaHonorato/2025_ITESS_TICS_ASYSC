# %% [markdown]
# ## ITESS_TICS_ANÁLISIS DE SEÑALES Y SISTEMAS DE COMUNICACIÓN
# ## AGOSTO-DICIEMBRE 2025
# ## DOCENTE FRANCISCO JAVIER MONTECILLO PUENTE
# ## ALUMNO 1 SANDRA ARACELI HERNANDEZ MUÑOZ
# ## ALUMNO 2 VANEZA GONZALES HONORATO
# ## TEMA 3: Sistemas lineales
# ## DESCRIPCIÓN: APROXIMACIÓN DE SEÑALES PERIODICAS USANDO SERIES DE FOURIER
# ## 11/12/25
# ## 🌸 Examen_ Sistemas lineales invariantes en el tiempo

# %%
import numpy as np
import matplotlib.pyplot as plt

#  Caso 1 
R = 10           # ohm
L = 10e-3        # H
C = 25e-9        # F
Vm = 5
f = 1000
beta = 0         # grados

# Funcion de entrada
fs = 48000
T = 0.02
N = int(fs * T)
t = np.linspace(0, T, N, endpoint=False)

# %%
# señales
omega0 = 2*np.pi*f
vin = Vm * np.cos(omega0 * t + np.deg2rad(beta))

# H(jw)
freqs = np.fft.rfftfreq(N, 1/fs)
omega = 2*np.pi*freqs
H = 1.0 / (1.0 - (omega**2)*L*C + 1j*omega*C*R)

# FFT entrada->salida en frecuencia y reconstrucción en tiempo
Vin = np.fft.rfft(vin)
Vout = H * Vin
vout = np.fft.irfft(Vout, n=N)

# %%
# --- Plots ---
plt.figure(figsize=(10,4))
plt.plot(t, vin, label='vin(t)', alpha=0.6)
plt.plot(t, vout, label='vout(t)', linewidth=0.9)
plt.title("Caso 1 - Respuesta temporal (vin y vout)")
plt.xlim(0, 5/f)
plt.xlabel("Tiempo (s)"); plt.ylabel("Voltaje (V)")
plt.legend(); plt.grid(); plt.show()

plt.figure(figsize=(10,3))
plt.plot(freqs, np.abs(Vout))
plt.title("Caso 1 - Espectro (magnitud) de la salida")
plt.xlim(0, fs/2); plt.xlabel("Frecuencia (Hz)"); plt.ylabel("|Vout(f)|")
plt.grid(); plt.show()

plt.figure(figsize=(10,3))
plt.plot(freqs, np.angle(Vout, deg=True))
plt.title("Caso 1 - Fase del espectro de la salida")
plt.xlim(0, fs/2); plt.xlabel("Frecuencia (Hz)"); plt.ylabel("Fase (°)")
plt.grid(); plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ===== CASO 1 =====
R = 10          # ohms
L = 10e-3       # 10 mH
C = 100e-9      # 100 nF
Vm = 5
f = 1000
beta = 0

fs = 48000
T = 0.02
N = int(fs * T)
t = np.linspace(0, T, N, endpoint=False)

omega0 = 2*np.pi*f
vin = Vm * np.cos(omega0 * t + np.deg2rad(beta))

freqs = np.fft.rfftfreq(N, 1/fs)
omega = 2*np.pi*freqs
H = 1.0 / (1.0 - (omega**2)*L*C + 1j*omega*C*R)

Vin = np.fft.rfft(vin)
Vout = H * Vin
vout = np.fft.irfft(Vout, n=N)

# --- Graficas ---
plt.figure(figsize=(10,4))
plt.plot(t, vin, label='vin(t)')
plt.plot(t, vout, label='vout(t)')
plt.title("Caso 1 - Respuesta temporal")
plt.grid(); plt.legend(); plt.show()

plt.figure(figsize=(10,3))
plt.plot(freqs, np.abs(Vout))
plt.title("Caso 1 - Espectro")
plt.grid(); plt.show()

plt.figure(figsize=(10,3))
plt.plot(freqs, np.angle(Vout, deg=True))
plt.title("Caso 1 - Fase")
plt.grid(); plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ===== CASO 2 =====
R = 47          # ohms
L = 22e-3       # 22 mH
C = 47e-9       # 47 nF
Vm = 5
f = 1500
beta = 20

fs = 48000
T = 0.02
N = int(fs * T)
t = np.linspace(0, T, N, endpoint=False)

omega0 = 2*np.pi*f
vin = Vm * np.cos(omega0 * t + np.deg2rad(beta))

freqs = np.fft.rfftfreq(N, 1/fs)
omega = 2*np.pi*freqs
H = 1.0 / (1.0 - (omega**2)*L*C + 1j*omega*C*R)

Vin = np.fft.rfft(vin)
Vout = H * Vin
vout = np.fft.irfft(Vout, n=N)

plt.figure(figsize=(10,4))
plt.plot(t, vin, label='vin(t)')
plt.plot(t, vout, label='vout(t)')
plt.title("Caso 2 - Respuesta temporal")
plt.grid(); plt.legend(); plt.show()

plt.figure(figsize=(10,3))
plt.plot(freqs, np.abs(Vout))
plt.title("Caso 2 - Espectro")
plt.grid(); plt.show()

plt.figure(figsize=(10,3))
plt.plot(freqs, np.angle(Vout, deg=True))
plt.title("Caso 2 - Fase")
plt.grid(); plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ===== CASO 3 =====
R = 100         # ohms
L = 33e-3       # 33 mH
C = 1e-6        # 1 µF
Vm = 5
f = 500
beta = -10

fs = 48000
T = 0.02
N = int(fs * T)
t = np.linspace(0, T, N, endpoint=False)

omega0 = 2*np.pi*f
vin = Vm * np.cos(omega0 * t + np.deg2rad(beta))

freqs = np.fft.rfftfreq(N, 1/fs)
omega = 2*np.pi*freqs
H = 1.0 / (1.0 - (omega**2)*L*C + 1j*omega*C*R)

Vin = np.fft.rfft(vin)
Vout = H * Vin
vout = np.fft.irfft(Vout, n=N)

plt.figure(figsize=(10,4))
plt.plot(t, vin, label='vin(t)')
plt.plot(t, vout, label='vout(t)')
plt.title("Caso 3 - Respuesta temporal")
plt.grid(); plt.legend(); plt.show()

plt.figure(figsize=(10,3))
plt.plot(freqs, np.abs(Vout))
plt.title("Caso 3 - Espectro")
plt.grid(); plt.show()

plt.figure(figsize=(10,3))
plt.plot(freqs, np.angle(Vout, deg=True))
plt.title("Caso 3 - Fase")
plt.grid(); plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ===== CASO 4 =====
R = 220         # ohms
L = 4.7e-3      # 4.7 mH
C = 220e-9      # 220 nF
Vm = 5
f = 2000
beta = 0

fs = 48000
T = 0.02
N = int(fs * T)
t = np.linspace(0, T, N, endpoint=False)

omega0 = 2*np.pi*f
vin = Vm * np.cos(omega0 * t + np.deg2rad(beta))

freqs = np.fft.rfftfreq(N, 1/fs)
omega = 2*np.pi*freqs
H = 1.0 / (1.0 - (omega**2)*L*C + 1j*omega*C*R)

Vin = np.fft.rfft(vin)
Vout = H * Vin
vout = np.fft.irfft(Vout, n=N)

plt.figure(figsize=(10,4))
plt.plot(t, vin, label='vin(t)')
plt.plot(t, vout, label='vout(t)')
plt.title("Caso 4 - Respuesta temporal")
plt.grid(); plt.legend(); plt.show()

plt.figure(figsize=(10,3))
plt.plot(freqs, np.abs(Vout))
plt.title("Caso 4 - Espectro")
plt.grid(); plt.show()

plt.figure(figsize=(10,3))
plt.plot(freqs, np.angle(Vout, deg=True))
plt.title("Caso 4 - Fase")
plt.grid(); plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ===== CASO 5 =====
R = 330         # ohms
L = 1e-3        # 1 mH
C = 10e-9       # 10 nF
Vm = 5
f = 3000
beta = 45

fs = 48000
T = 0.02
N = int(fs * T)
t = np.linspace(0, T, N, endpoint=False)

omega0 = 2*np.pi*f
vin = Vm * np.cos(omega0 * t + np.deg2rad(beta))

freqs = np.fft.rfftfreq(N, 1/fs)
omega = 2*np.pi*freqs
H = 1.0 / (1.0 - (omega**2)*L*C + 1j*omega*C*R)

Vin = np.fft.rfft(vin)
Vout = H * Vin
vout = np.fft.irfft(Vout, n=N)

plt.figure(figsize=(10,4))
plt.plot(t, vin, label='vin(t)')
plt.plot(t, vout, label='vout(t)')
plt.title("Caso 5 - Respuesta temporal")
plt.grid(); plt.legend(); plt.show()

plt.figure(figsize=(10,3))
plt.plot(freqs, np.abs(Vout))
plt.title("Caso 5 - Espectro")
plt.grid(); plt.show()

plt.figure(figsize=(10,3))
plt.plot(freqs, np.angle(Vout, deg=True))
plt.title("Caso 5 - Fase")
plt.grid(); plt.show()
